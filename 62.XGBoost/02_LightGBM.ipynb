# %% [markdown]
# # Light GBM

# %%
from lightgbm import LGBMClassifier, plot_importance, plot_metric, plot_tree

# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
cancer = load_breast_cancer()
X_train, X_test, y_train, y_test = train_test_split(
    cancer.data, cancer.target, stratify=cancer.target, test_size=0.2, random_state=2021
)

# %%
lgbm = LGBMClassifier(n_estimators=400)
evals = [(X_test, y_test)]
lgbm.fit(X_train, y_train, early_stopping_rounds=100, eval_metric='logloss', eval_set=evals, verbose=True)
# Out:
# [1]	valid_0's binary_logloss: 0.581212	valid_0's binary_logloss: 0.581212
# Training until validation scores don't improve for 100 rounds.
# [2]	valid_0's binary_logloss: 0.520053	valid_0's binary_logloss: 0.520053
# [3]	valid_0's binary_logloss: 0.468667	valid_0's binary_logloss: 0.468667
# [4]	valid_0's binary_logloss: 0.426047	valid_0's binary_logloss: 0.426047
# [5]	valid_0's binary_logloss: 0.388153	valid_0's binary_logloss: 0.388153
# [6]	valid_0's binary_logloss: 0.354201	valid_0's binary_logloss: 0.354201
# [7]	valid_0's binary_logloss: 0.3259	valid_0's binary_logloss: 0.3259
# [8]	valid_0's binary_logloss: 0.300288	valid_0's binary_logloss: 0.300288
# [9]	valid_0's binary_logloss: 0.28006	valid_0's binary_logloss: 0.28006
# [10]	valid_0's binary_logloss: 0.26029	valid_0's binary_logloss: 0.26029
# [11]	valid_0's binary_logloss: 0.242461	valid_0's binary_logloss: 0.242461
# [12]	valid_0's binary_logloss: 0.224901	valid_0's binary_logloss: 0.224901
# ...

# %%
pred = lgbm.predict(X_test)
accuracy_score(y_test, pred)
# Out:
# 1.0

# %%
plot_metric(lgbm);

# %%
plot_importance(lgbm, figsize=(10,12));

# %%
plot_tree(lgbm, figsize=(28,24));
