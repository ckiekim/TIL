# %%
import sys
import gym
import pylab
import random
import numpy as np
from collections import deque
from keras.layers import Dense
from keras.optimizers import Adam
from keras.models import Sequential

EPISODES = 300
# Out:
# Using TensorFlow backend.

# %%
class DQNAgent:
    def __init__(self, state_size, action_size):
        self.render = False
        self.load_model = False

        # 상태와 행동의 크기 정의
        self.state_size = state_size
        self.action_size = action_size

        # DQN 하이퍼파라미터
        self.discount_factor = 0.99
        self.learning_rate = 0.001
        self.epsilon = 1.0
        self.epsilon_decay = 0.999
        self.epsilon_min = 0.01
        self.batch_size = 64
        self.train_start = 1000

        # 리플레이 메모리, 최대 크기 2000
        self.memory = deque(maxlen=2000)

        # 모델과 타깃 모델 생성
        self.model = self.build_model()
        self.target_model = self.build_model()

        # 타깃 모델 초기화
        self.update_target_model()

        if self.load_model:
            self.model.load_weights("./save_model/cartpole_dqn_trained.h5")

    # 상태가 입력, 큐함수가 출력인 인공신경망 생성
    def build_model(self):
        model = Sequential()
        model.add(Dense(24, input_dim=self.state_size, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(24, activation='relu',
                        kernel_initializer='he_uniform'))
        model.add(Dense(self.action_size, activation='linear',
                        kernel_initializer='he_uniform'))
        model.summary()
        model.compile(loss='mse', optimizer=Adam(lr=self.learning_rate))
        return model

    # 타깃 모델을 모델의 가중치로 업데이트
    def update_target_model(self):
        self.target_model.set_weights(self.model.get_weights())

    # 입실론 탐욕 정책으로 행동 선택
    def get_action(self, state):
        if np.random.rand() <= self.epsilon:
            return random.randrange(self.action_size)
        else:
            q_value = self.model.predict(state)
            return np.argmax(q_value[0])

    # 샘플 <s, a, r, s'>을 리플레이 메모리에 저장
    def append_sample(self, state, action, reward, next_state, done):
        self.memory.append((state, action, reward, next_state, done))

    # 리플레이 메모리에서 무작위로 추출한 배치로 모델 학습
    def train_model(self):
        if self.epsilon > self.epsilon_min:
            self.epsilon *= self.epsilon_decay

        # 메모리에서 배치 크기만큼 무작위로 샘플 추출
        mini_batch = random.sample(self.memory, self.batch_size)

        states = np.zeros((self.batch_size, self.state_size))
        next_states = np.zeros((self.batch_size, self.state_size))
        actions, rewards, dones = [], [], []

        for i in range(self.batch_size):
            states[i] = mini_batch[i][0]
            actions.append(mini_batch[i][1])
            rewards.append(mini_batch[i][2])
            next_states[i] = mini_batch[i][3]
            dones.append(mini_batch[i][4])

        # 현재 상태에 대한 모델의 큐함수
        # 다음 상태에 대한 타깃 모델의 큐함수
        target = self.model.predict(states)
        target_val = self.target_model.predict(next_states)

        # 벨만 최적 방정식을 이용한 업데이트 타깃
        for i in range(self.batch_size):
            if dones[i]:
                target[i][actions[i]] = rewards[i]
            else:
                target[i][actions[i]] = rewards[i] + self.discount_factor * (
                    np.amax(target_val[i]))

        self.model.fit(states, target, batch_size=self.batch_size,
                       epochs=1, verbose=0)

# %%
# CartPole-v1 환경, 최대 타임스텝 수가 500
env = gym.make('CartPole-v1')
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
# DQN 에이전트 생성
agent = DQNAgent(state_size, action_size)
scores, episodes = [], []

for e in range(EPISODES):
    done = False
    score = 0
    # env 초기화
    state = env.reset()
    state = np.reshape(state, [1, state_size])

    while not done:
        if agent.render:
            env.render()
        
        # 현재 상태로 행동을 선택
        action = agent.get_action(state)
        # 선택한 행동으로 환경에서 한 타임스텝 진행
        next_state, reward, done, info = env.step(action)
        next_state = np.reshape(next_state, [1, state_size])
        # 에피소드가 중간에 끝나면 -100 보상
        reward = reward if not done or score == 499 else -100

        # 리플레이 메모리에 샘플 <s, a, r, s'> 저장
        agent.append_sample(state, action, reward, next_state, done)
        # 매 타임스텝마다 학습
        if len(agent.memory) >= agent.train_start:
            agent.train_model()

        score += reward
        state = next_state

        if done:
            # 각 에피소드마다 타깃 모델을 모델의 가중치로 업데이트
            agent.update_target_model()

            score = score if score == 500 else score + 100
            # 에피소드마다 학습 결과 출력
            scores.append(score)
            episodes.append(e)
            if e%20 == 0:
                pylab.plot(episodes, scores, 'b')
                pylab.savefig("./graph/cartpole_dqn_"+str(e)+".png")
            print("episode:", e, "  score:", score, "  memory length:",
                  len(agent.memory), "  epsilon:", agent.epsilon)

            # 이전 10개 에피소드의 점수 평균이 490보다 크면 학습 중단
            if np.mean(scores[-min(10, len(scores)):]) > 490:
                agent.model.save_weights("./model/cartpole_dqn_"+str(e)+".h5")
                sys.exit()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0914 09:53:33.804618 14688 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# W0914 09:53:33.816636 14688 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# W0914 09:53:33.819579 14688 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# W0914 09:53:33.870489 14688 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\optimizers.py:793: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# W0914 09:53:33.942289 14688 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:190: The name tf.get_default_session is deprecated. Please use tf.compat.v1.get_default_session instead.
#
# W0914 09:53:33.943288 14688 deprecation_wrapper.py:119] From C:\ProgramData\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:197: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_2 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_3 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 24)                120
# _________________________________________________________________
# dense_5 (Dense)              (None, 24)                600
# _________________________________________________________________
# dense_6 (Dense)              (None, 2)                 50
# =================================================================
# Total params: 770
# Trainable params: 770
# Non-trainable params: 0
# _________________________________________________________________
# episode: 0   score: 19.0   memory length: 20   epsilon: 1.0
# episode: 1   score: 17.0   memory length: 38   epsilon: 1.0
# episode: 2   score: 15.0   memory length: 54   epsilon: 1.0
# episode: 3   score: 19.0   memory length: 74   epsilon: 1.0
# episode: 4   score: 13.0   memory length: 88   epsilon: 1.0
# episode: 5   score: 12.0   memory length: 101   epsilon: 1.0
# episode: 6   score: 12.0   memory length: 114   epsilon: 1.0
# episode: 7   score: 28.0   memory length: 143   epsilon: 1.0
# episode: 8   score: 26.0   memory length: 170   epsilon: 1.0
# episode: 9   score: 24.0   memory length: 195   epsilon: 1.0
# episode: 10   score: 19.0   memory length: 215   epsilon: 1.0
# episode: 11   score: 9.0   memory length: 225   epsilon: 1.0
# episode: 12   score: 25.0   memory length: 251   epsilon: 1.0
# episode: 13   score: 16.0   memory length: 268   epsilon: 1.0
# episode: 14   score: 18.0   memory length: 287   epsilon: 1.0
# episode: 15   score: 13.0   memory length: 301   epsilon: 1.0
# episode: 16   score: 31.0   memory length: 333   epsilon: 1.0
# episode: 17   score: 12.0   memory length: 346   epsilon: 1.0
# episode: 18   score: 23.0   memory length: 370   epsilon: 1.0
# episode: 19   score: 16.0   memory length: 387   epsilon: 1.0
# episode: 20   score: 34.0   memory length: 422   epsilon: 1.0
# episode: 21   score: 21.0   memory length: 444   epsilon: 1.0
# episode: 22   score: 11.0   memory length: 456   epsilon: 1.0
# episode: 23   score: 18.0   memory length: 475   epsilon: 1.0
# episode: 24   score: 16.0   memory length: 492   epsilon: 1.0
# episode: 25   score: 36.0   memory length: 529   epsilon: 1.0
# episode: 26   score: 65.0   memory length: 595   epsilon: 1.0
# episode: 27   score: 15.0   memory length: 611   epsilon: 1.0
# episode: 28   score: 12.0   memory length: 624   epsilon: 1.0
# episode: 29   score: 29.0   memory length: 654   epsilon: 1.0
# episode: 30   score: 21.0   memory length: 676   epsilon: 1.0
# episode: 31   score: 10.0   memory length: 687   epsilon: 1.0
# episode: 32   score: 20.0   memory length: 708   epsilon: 1.0
# episode: 33   score: 26.0   memory length: 735   epsilon: 1.0
# episode: 34   score: 22.0   memory length: 758   epsilon: 1.0
# episode: 35   score: 13.0   memory length: 772   epsilon: 1.0
# episode: 36   score: 24.0   memory length: 797   epsilon: 1.0
# episode: 37   score: 44.0   memory length: 842   epsilon: 1.0
# episode: 38   score: 28.0   memory length: 871   epsilon: 1.0
# episode: 39   score: 65.0   memory length: 937   epsilon: 1.0
# episode: 40   score: 13.0   memory length: 951   epsilon: 1.0
# episode: 41   score: 50.0   memory length: 1002   epsilon: 0.997002999
# episode: 42   score: 18.0   memory length: 1021   epsilon: 0.9782294672887405
# episode: 43   score: 38.0   memory length: 1060   epsilon: 0.9407945259609451
# episode: 44   score: 14.0   memory length: 1075   epsilon: 0.9267809647166116
# episode: 45   score: 18.0   memory length: 1094   epsilon: 0.9093297114626595
# episode: 46   score: 20.0   memory length: 1115   epsilon: 0.8904235427767183
# episode: 47   score: 13.0   memory length: 1129   epsilon: 0.8780383184956015
# episode: 48   score: 10.0   memory length: 1140   epsilon: 0.8684280445126921
# episode: 49   score: 48.0   memory length: 1189   epsilon: 0.8268805241487632
# episode: 50   score: 37.0   memory length: 1227   epsilon: 0.7960334462988972
# episode: 51   score: 71.0   memory length: 1299   epsilon: 0.7407070321560997
# episode: 52   score: 28.0   memory length: 1328   epsilon: 0.7195245662400531
# episode: 53   score: 19.0   memory length: 1348   epsilon: 0.7052699677998009
# episode: 54   score: 100.0   memory length: 1449   epsilon: 0.6374846057319378
# episode: 55   score: 18.0   memory length: 1468   epsilon: 0.6254807928315229
# episode: 56   score: 40.0   memory length: 1509   epsilon: 0.6003423698268052
# episode: 57   score: 68.0   memory length: 1578   epsilon: 0.5602962074911925
# episode: 58   score: 66.0   memory length: 1645   epsilon: 0.5239687596143511
# episode: 59   score: 108.0   memory length: 1754   epsilon: 0.46983310087889063
# episode: 60   score: 120.0   memory length: 1875   epsilon: 0.41626288125048977
# episode: 61   score: 50.0   memory length: 1926   epsilon: 0.39555564385952335
# episode: 62   score: 129.0   memory length: 2000   epsilon: 0.34731301240586104
# episode: 63   score: 79.0   memory length: 2000   epsilon: 0.3205974863526735
# episode: 64   score: 114.0   memory length: 2000   epsilon: 0.2857533029063643
# episode: 65   score: 95.0   memory length: 2000   epsilon: 0.2595841245128649
# episode: 66   score: 135.0   memory length: 2000   epsilon: 0.22656067366330018
# episode: 67   score: 164.0   memory length: 2000   epsilon: 0.1920835106763006
# episode: 68   score: 236.0   memory length: 2000   epsilon: 0.1515342466416174
# episode: 69   score: 153.0   memory length: 2000   epsilon: 0.1298960608156215
# episode: 70   score: 253.0   memory length: 2000   epsilon: 0.10074650533676789
# episode: 71   score: 232.0   memory length: 2000   epsilon: 0.07979740108087201
# episode: 72   score: 177.0   memory length: 2000   epsilon: 0.06677988260908838
# episode: 73   score: 118.0   memory length: 2000   epsilon: 0.05928417084769743
# episode: 74   score: 200.0   memory length: 2000   epsilon: 0.048484384154007916
# episode: 75   score: 213.0   memory length: 2000   epsilon: 0.03913959829012518
# episode: 76   score: 189.0   memory length: 2000   epsilon: 0.032363771549110715
# episode: 77   score: 473.0   memory length: 2000   epsilon: 0.02014190512696517
# episode: 78   score: 191.0   memory length: 2000   epsilon: 0.01662165582555119
# episode: 79   score: 183.0   memory length: 2000   epsilon: 0.013826877620138877
# episode: 80   score: 230.0   memory length: 2000   epsilon: 0.010973670081346181
# episode: 81   score: 180.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 82   score: 193.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 83   score: 173.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 84   score: 180.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 85   score: 180.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 86   score: 190.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 87   score: 165.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 88   score: 183.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 89   score: 169.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 90   score: 212.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 91   score: 170.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 92   score: 200.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 93   score: 157.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 94   score: 178.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 95   score: 176.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 96   score: 151.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 97   score: 163.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 98   score: 182.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 99   score: 184.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 100   score: 171.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 101   score: 194.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 102   score: 194.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 103   score: 180.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 104   score: 125.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 105   score: 162.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 106   score: 187.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 107   score: 193.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 108   score: 169.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 109   score: 192.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 110   score: 203.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 111   score: 152.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 112   score: 217.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 113   score: 302.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 114   score: 223.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 115   score: 184.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 116   score: 222.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 117   score: 181.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 118   score: 178.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 119   score: 189.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 120   score: 173.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 121   score: 187.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 122   score: 418.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 123   score: 212.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 124   score: 240.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 125   score: 199.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 126   score: 312.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 127   score: 226.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 128   score: 287.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 129   score: 253.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 130   score: 268.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 131   score: 383.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 132   score: 385.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 133   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 134   score: 269.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 135   score: 293.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 136   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 137   score: 394.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 138   score: 227.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 139   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 140   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 141   score: 296.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 142   score: 263.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 143   score: 279.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 144   score: 241.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 145   score: 263.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 146   score: 321.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 147   score: 259.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 148   score: 302.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 149   score: 250.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 150   score: 281.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 151   score: 288.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 152   score: 288.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 153   score: 254.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 154   score: 243.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 155   score: 280.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 156   score: 292.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 157   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 158   score: 259.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 159   score: 266.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 160   score: 359.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 161   score: 299.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 162   score: 255.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 163   score: 283.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 164   score: 306.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 165   score: 488.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 166   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 167   score: 273.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 168   score: 477.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 169   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 170   score: 361.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 171   score: 330.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 172   score: 312.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 173   score: 334.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 174   score: 350.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 175   score: 401.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 176   score: 454.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 177   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 178   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 179   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 180   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 181   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 182   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 183   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 184   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# episode: 185   score: 500.0   memory length: 2000   epsilon: 0.009998671593271896
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3334: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
