# %% [markdown]
# # 물체 탐지(Object detection) - YOLO v3
#
# ### Darknet download
# - https://github.com/pjreddie/darknet download
#
# ### 학습된 모델 다운로드
# - wget wget https://pjreddie.com/media/files/yolov3.weights

# %% [markdown]
# ### Python Keras로 물체 YOLO 탐지 실행
# - https://github.com/qqwweee/keras-yolo3 download
# - darknet에서 yolov3.weights 복사
# - 명령창에서 python convert.py yolov3-tiny.cfg yolov3.weights yolov3.h5 실행

# %% [markdown]
# ### 모델구조 보기

# %%
from keras.models import load_model
from keras.utils.vis_utils import plot_model

# 모델 파일 로딩
model = load_model('keras_yolo3/yolov3.h5')

# 구조를 이미지로 저장
plot_model(model, show_shapes=True, to_file='yolo3_structure.png')

from IPython.display import Image
Image('yolo3_structure.png')
# Out:
# Using TensorFlow backend.
# C:\Users\ckkim\.conda\envs\tf2\lib\site-packages\keras\engine\saving.py:341: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %% [markdown]
# ### 탐지 대상 이미지 다운로드
# - wget -O street_view.jpg http://beltlineorg-wpengine.netdna-ssl.com/wp-content/uploads/2012/12/IMG_5669-flickr-websized.jpg

# %%
from IPython.display import Image, display
display(Image(filename='street_view.jpg'))

# %% [markdown]
# ### 물체 탐지 실행
# 다음의 파일이 필요하다.
#
# - yolov3.h5 : 모델 파일
# - coco.names : 클래스 이름

# %%
# !type darknet-master\data\coco.names
# Out:
# person
# bicycle
# car
# motorbike
# aeroplane
# bus
# train
# truck
# boat
# traffic light
# fire hydrant
# stop sign
# parking meter
# bench
# bird
# cat
# dog
# horse
# sheep
# cow
# elephant
# bear
# zebra
# giraffe
# backpack
# umbrella
# handbag
# tie
# suitcase
# frisbee
# skis
# snowboard
# sports ball
# kite
# baseball bat
# baseball glove
# skateboard
# surfboard
# tennis racket
# bottle
# wine glass
# cup
# fork
# knife
# spoon
# bowl
# banana
# apple
# sandwich
# orange
# broccoli
# carrot
# hot dog
# pizza
# donut
# cake
# chair
# sofa
# pottedplant
# bed
# diningtable
# toilet
# tvmonitor
# laptop
# mouse
# remote
# keyboard
# cell phone
# microwave
# oven
# toaster
# sink
# refrigerator
# book
# clock
# vase
# scissors
# teddy bear
# hair drier
# toothbrush

# %%
from IPython.display import display 
from PIL import Image
from keras_yolo3.yolo import YOLO

def do_object_detection(file, model_path, class_path):
    yolo = YOLO(model_path=model_path, classes_path=class_path)

    # 이미지 로딩
    image = Image.open(file)

    # 실행
    result_image = yolo.detect_image(image)

    # 실행 결과 표시
    display(result_image)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-e7255f2d7f87> in <module>
#       1 from IPython.display import display
#       2 from PIL import Image
# ----> 3 from keras_yolo3.yolo import YOLO
#       4
#       5 def do_object_detection(file, model_path, class_path):
#
# d:\Workspace\TIL\41.ImageDetection\keras_yolo3\yolo.py in <module>
#      14 from PIL import Image, ImageFont, ImageDraw
#      15
# ---> 16 from yolo3.model import yolo_eval, yolo_body, tiny_yolo_body
#      17 from yolo3.utils import letterbox_image
#      18 import os
#
# ModuleNotFoundError: No module named 'yolo3'
